# %% [markdown]
# # HumorVibes — what the label can support
#
# A humor model is usually scored against 1.0. On a crowd-rated corpus that is the wrong denominator: the label is a **mean over a finite number of votes**, so it carries sampling error, and no predictor can track a noisy measurement better than a second independent measurement of it does.
#
# This notebook displays three measurements made on 2026-07-26 over **2,186,939 New Yorker caption-contest captions in 371 contests** — the only corpus in this project that ships the raw vote breakdown per item, which is what makes the label's own error visible:
#
# 1. **The ceiling.** How high can any predictor score against this label?
# 2. **The bound.** How much of a caption's reception is in its words at all?
# 3. **A null.** Do different joke FORMS sit in different surprisal regimes?
#
# **Framing.** The parent project's thesis is that a joke is a *controlled prediction error with a cheap, audience-permitted repair* — motivated by the predictive-processing shorthand ‘the brain is a surprise-reduction engine’, held as a framework rather than a conclusion. This notebook supplies the discipline around that thesis: the ceiling and bound put hard numbers on how much any text model could see here (context dominates text), and the form null is the thesis behaving as predicted — raw surprisal does not rank humor categories. Tenet-by-tenet evidence status: [docs/THESIS_AND_EVIDENCE.md](https://github.com/aidonerightcorp/humorvibes-jestry/blob/main/docs/THESIS_AND_EVIDENCE.md).
#
# Every number is read from a local receipt, embedded below with its sha256 and mtime. This is the static public edition: every figure renders from the embedded receipts, nothing depends on a live session, and the run is fully reproducible offline.
#
# Build nonce **`49f7bc7743d0`** — it identifies this exact build and appears in the executive summary.

# %%
# ---- receipts, embedded at build time (no dataset mount, nothing to wait for) ----
import json
RECEIPTS = json.loads(r'''{
 "ceiling": {
  "receipt_type": "caption_label_ceiling",
  "receipt_version": 1,
  "ts": "2026-07-26T16:41:16",
  "question": "what is the highest spearman any predictor can reach against this corpus's published funniness, given the label is a mean over a finite vote sample?",
  "protocol": {
   "scope": "within contest; the drawing and the vote scale are held fixed",
   "min_votes_per_caption": 20,
   "min_captions_per_contest": 200,
   "split_half": "votes dealt into two disjoint halves per caption (multivariate hypergeometric), Spearman across captions, Spearman-Brown to full length",
   "analytic": "multinomial sampling variance of each caption mean over the observed within-contest variance of means",
   "ceiling": "sqrt(reliability) — the classical attenuation bound, derived for Pearson and applied here to Spearman as an approximation",
   "seed": 20260726
  },
  "n_captions_used": 2052842,
  "n_captions_dropped": 134097,
  "n_contests": 360,
  "headline": {
   "median_reliability_split_half": 0.6826504843181436,
   "median_reliability_analytic": 0.7968106992014228,
   "median_ceiling": 0.8262266476511767,
   "p10_ceiling": 0.749003010029548,
   "p90_ceiling": 0.8842127829620519,
   "median_abs_disagreement_between_estimators": 0.10878490359432569
  },
  "by_vote_count": [
   {
    "median_votes_lo": 20,
    "median_votes_hi": 50,
    "contests": 47,
    "reliability": 0.6172566371681416,
    "ceiling": 0.7856568189535057
   },
   {
    "median_votes_lo": 50,
    "median_votes_hi": 100,
    "contests": 205,
    "reliability": 0.6749701868292036,
    "ceiling": 0.8215656923394523
   },
   {
    "median_votes_lo": 100,
    "median_votes_hi": 200,
    "contests": 95,
    "reliability": 0.7209004860578152,
    "ceiling": 0.8490585881185203
   },
   {
    "median_votes_lo": 200,
    "median_votes_hi": 1000000000,
    "contests": 13,
    "reliability": 0.8230447831460013,
    "ceiling": 0.9072181563141256
   }
  ],
  "runtime_s": 33.4
 },
 "portability": {
  "receipt_type": "caption_portability",
  "receipt_version": 1,
  "ts": "2026-07-26T16:43:32",
  "question": "does a caption's funniness travel with its words to a different drawing?",
  "protocol": {
   "standing": "percentile rank of the crowd mean within its own contest, ties averaged",
   "pairing": "texts normalised for case/whitespace/curly-quotes; first occurrence per contest; the two lowest-numbered contests when a text appears in more",
   "control": "split-half of the SAME captions' own votes, Spearman-Brown lifted to full length — the value arm 1 would take if context were irrelevant",
   "min_votes_per_caption": 20,
   "min_captions_per_contest": 200,
   "seed": 20260726
  },
  "n_pairs": 2173,
  "n_texts_in_3_or_more_contests": 84,
  "results": {
   "cross_context_spearman": 0.1689,
   "same_context_ceiling_spearman": 0.6912707760764298,
   "same_context_half_split_spearman": 0.5282,
   "placebo_spearman": 0.0111,
   "portable_share": 0.24433262021961374,
   "text_only_predictor_bound": 0.41097445176069036
  },
  "text_only_bound_derivation": "standing = T(text) + C(fit with this drawing) + E(vote noise); C and E independent across contests makes arm 1 equal to var(T)/var(standing), so a perfect text-only predictor correlates with standing at sqrt(arm 1). Read as an UPPER bound: texts that recur across contests skew generic, which inflates arm 1.",
  "verdict": "a minority of standing travels with the words (24% of what the label's reliability would allow); most of a caption's reception belongs to its fit with the drawing, which bounds text-only models",
  "examples_most_context_dependent": [
   {
    "text": "He still doesn't get it.",
    "contest_a": "559",
    "standing_a": 0.981,
    "contest_b": "778.csv",
    "standing_b": 0.01,
    "votes_a": 79.0,
    "votes_b": 68.0
   },
   {
    "text": "I’m suddenly feeling profoundly domesticated.",
    "contest_a": "883",
    "standing_a": 0.99,
    "contest_b": "886",
    "standing_b": 0.025,
    "votes_a": 742.0,
    "votes_b": 78.0
   },
   {
    "text": "Haven't seen him.",
    "contest_a": "632",
    "standing_a": 0.054,
    "contest_b": "824.csv",
    "standing_b": 0.997,
    "votes_a": 37.0,
    "votes_b": 1817.0
   },
   {
    "text": "No, YOU'RE a mirage",
    "contest_a": "552",
    "standing_a": 0.993,
    "contest_b": "728.csv",
    "standing_b": 0.054,
    "votes_a": 176.0,
    "votes_b": 41.0
   },
   {
    "text": "I am the Ghost of Breakfast Past.",
    "contest_a": "642",
    "standing_a": 0.964,
    "contest_b": "772.csv",
    "standing_b": 0.026,
    "votes_a": 251.0,
    "votes_b": 64.0
   },
   {
    "text": "Do you have the Age?",
    "contest_a": "646",
    "standing_a": 0.041,
    "contest_b": "827.csv",
    "standing_b": 0.976,
    "votes_a": 278.0,
    "votes_b": 491.0
   }
  ],
  "examples_most_portable": [
   {
    "text": "Funny seeing you here",
    "contest_a": "605",
    "standing_a": 0.473,
    "contest_b": "753.csv",
    "standing_b": 0.474,
    "votes_a": 100.0,
    "votes_b": 72.0
   },
   {
    "text": "It's a side effect of the Paleo Diet.",
    "contest_a": "537",
    "standing_a": 0.603,
    "contest_b": "755.csv",
    "standing_b": 0.605,
    "votes_a": 117.0,
    "votes_b": 57.0
   },
   {
    "text": "living the dream",
    "contest_a": "677.csv",
    "standing_a": 0.648,
    "contest_b": "809.csv",
    "standing_b": 0.649,
    "votes_a": 136.0,
    "votes_b": 79.0
   },
   {
    "text": "Where’s Billy?",
    "contest_a": "785.csv",
    "standing_a": 0.298,
    "contest_b": "885",
    "standing_b": 0.299,
    "votes_a": 50.0,
    "votes_b": 91.0
   },
   {
    "text": "It's not as bad as it looks.",
    "contest_a": "565",
    "standing_a": 0.713,
    "contest_b": "651",
    "standing_b": 0.713,
    "votes_a": 36.0,
    "votes_b": 246.0
   },
   {
    "text": "I'm not sure you understand the gravity of the situation.",
    "contest_a": "639",
    "standing_a": 0.993,
    "contest_b": "773.csv",
    "standing_b": 0.993,
    "votes_a": 240.0,
    "votes_b": 859.0
   }
  ],
  "caveats": "a text submitted to two contests is not a random caption — it is more likely to be generic, which if anything HELPS it travel, so this is an upper bound on portability rather than a lower one",
  "runtime_s": 47.7
 },
 "form_signal": {
  "receipt_type": "form_signal_study",
  "receipt_version": 1,
  "ts": "2026-07-26T13:47:20",
  "instrument": "gemma2-full-nll (gemma-2-2b-it Q4_K_M, llama.cpp)",
  "measure": "S only (mean punchline NLL given setup); R not measured",
  "per_form_requested": 8,
  "sampling": "deterministic: sha256(text) order, English only, 20-300 chars",
  "errors": 0,
  "elapsed_min": 59.44,
  "per_form": {
   "knock_knock": {
    "n": 8,
    "mean_S": 3.7281,
    "ci95": [
     2.9145,
     4.4607
    ]
   },
   "what_do_you_call": {
    "n": 8,
    "mean_S": 6.6803,
    "ci95": [
     4.7591,
     8.8552
    ]
   },
   "whats_the_difference": {
    "n": 8,
    "mean_S": 4.6928,
    "ci95": [
     3.9052,
     5.4458
    ]
   },
   "walks_into_bar": {
    "n": 8,
    "mean_S": 4.4791,
    "ci95": [
     3.1719,
     5.8094
    ]
   },
   "light_bulb": {
    "n": 8,
    "mean_S": 3.8145,
    "ci95": [
     3.0512,
     4.6822
    ]
   },
   "q_and_a": {
    "n": 8,
    "mean_S": 3.8739,
    "ci95": [
     3.1194,
     4.555
    ]
   },
   "yo_mama": {
    "n": 8,
    "mean_S": 4.178,
    "ci95": [
     3.309,
     5.025
    ]
   },
   "doctor_doctor": {
    "n": 8,
    "mean_S": 4.7034,
    "ci95": [
     3.6539,
     5.8835
    ]
   },
   "limerick": {
    "n": 8,
    "mean_S": 3.8558,
    "ci95": [
     3.2619,
     4.4864
    ]
   },
   "setup_punchline": {
    "n": 8,
    "mean_S": 4.0819,
    "ci95": [
     3.0852,
     5.1267
    ]
   },
   "control_proverb": {
    "n": 8,
    "mean_S": 3.6522,
    "ci95": [
     2.2976,
     5.1979
    ]
   }
  },
  "verdict": "0/10 joke forms have a mean-S CI strictly above the proverb control's upper bound (5.198); 10 overlap it",
  "caveat": "S is model surprisal, not funniness; these items carry no human grade"
 },
 "census": {
  "declared_styles": {
   "absurd": 3210,
   "anti_joke": 3305,
   "aviation": 4,
   "christmas": 2,
   "chuck_norris_fact": 5988,
   "clean": 3236,
   "dad": 1,
   "dad_joke": 3322,
   "general": 2772,
   "knock-knock": 5,
   "legal": 125,
   "medical": 66,
   "military": 23,
   "misc": 103,
   "one_liner": 3324,
   "programming": 59,
   "pun": 2767,
   "science": 3677,
   "showerthought": 3130,
   "tech": 3169
  },
  "distinct_families": 217,
  "distinct_languages": 62,
  "distinct_licences": 34,
  "distinct_sources": 767,
  "families": {
   "MemeCap (eujhwang/meme-cap)": 6382,
   "api.chucknorris.io": 5988,
   "gutenberg (public-domain jest books)": 44292,
   "hf:IgorVolochay/russian_jokes": 150010,
   "hf:JonaszPotoniec/dowcipy-polish-jokes-dataset": 8986,
   "hf:Kalloniatis/Greek-Humor-Dataset": 7168,
   "hf:Rapidata/multilingual-llm-jokes-4o-claude-gemini": 9907,
   "hf:Superar/Puntuguese": 5691,
   "hf:ellamind/grips-multilingual": 6358,
   "hf:hfht/SemEval-2021-Task-7-Jokes": 5583,
   "hf:israel/ProverbEval": 8283,
   "hf:oHenri/chinese_xiehouyu": 7272,
   "hf:shuttie/dadjokes": 51513,
   "hf:vislupus/alpaca-bulgarian-jokes": 55965,
   "hf:yoonholee/humor-greats-public-domain": 9684,
   "hf:ysharma/short_jokes": 116718,
   "nextml/caption-contest-data (all contests)": 2246476,
   "reddit:r/AntiJokes (arctic-shift)": 3305,
   "reddit:r/Jokes (bulk)": 98516,
   "reddit:r/cleanjokes (arctic-shift)": 3236,
   "reddit:r/dadjokes (arctic-shift)": 3266,
   "reddit:r/oneliners (arctic-shift)": 3324,
   "taivop/joke-dataset (all dumps)": 198573,
   "wiktionary (en)": 53396,
   "wiktionary (ru)": 4493
  },
  "files": 117,
  "graded": 2587825,
  "graded_share": 0.8177,
  "items": 3164600,
  "languages": {
   "am": 5852,
   "ar": 3295,
   "az": 140,
   "bg": 56008,
   "bn": 1,
   "ca": 90,
   "cs": 1273,
   "cy": 240,
   "da": 1943,
   "de": 5606,
   "el": 7368,
   "en": 2819933,
   "es": 7713,
   "eu": 10,
   "fa": 410,
   "fi": 2490,
   "fr": 2863,
   "ga": 60,
   "gl": 136,
   "he": 368,
   "hi": 527,
   "ht": 1,
   "hu": 743,
   "id": 1467,
   "is": 148,
   "it": 3551,
   "ja": 3626,
   "ka": 62,
   "ko": 817,
   "la": 101,
   "lt": 1619,
   "mk": 158,
   "mr": 8,
   "ms": 88,
   "nl": 2487,
   "nn": 1,
   "no": 1,
   "om": 1983,
   "pl": 14792,
   "pt": 10806,
   "ro": 932,
   "ru": 155535,
   "sh": 130,
   "sq": 28,
   "sr": 1,
   "sv": 2220,
   "sw": 63,
   "ta": 993,
   "te": 279,
   "th": 350,
   "ti": 448,
   "tl": 1,
   "tr": 2972,
   "uk": 91,
   "unknown": 9827,
   "ur": 1847,
   "vi": 2463,
   "yi": 80,
   "yo": 624,
   "zh": 26929
  },
  "licence_classes": {
   "noncommercial": 59537,
   "redistributable": 511110,
   "research_only": 2580879,
   "unclassified": 13074
  },
  "record_kinds": {
   "explained_joke": 55,
   "frame": 705,
   "idiom": 52664,
   "meme_caption": 6382,
   "meme_template": 271,
   "proverb": 19545,
   "public_domain_humor": 33760,
   "ranked_caption": 2186939,
   "simile": 687,
   "unfunned_pair": 1352
  },
  "sources": {
   "en.wiktionary:Category:Chinese idioms": 16880,
   "en.wiktionary:Category:English idioms": 10066,
   "hf:IgorVolochay/russian_jokes": 150010,
   "hf:JonaszPotoniec/dowcipy-polish-jokes-dataset": 8986,
   "hf:Rapidata/multilingual-llm-jokes-4o-claude-gemini": 9907,
   "hf:shuttie/dadjokes": 51513,
   "hf:vislupus/alpaca-bulgarian-jokes": 55965,
   "hf:yoonholee/humor-greats-public-domain": 9684,
   "hf:ysharma/short_jokes": 116718,
   "nextml/caption-contest-data (New Yorker Caption Contest)": 59537,
   "nextml/caption-contest-data contest 619": 9529,
   "nextml/caption-contest-data contest 641": 9018,
   "nextml/caption-contest-data contest 651": 9199,
   "nextml/caption-contest-data contest 652": 9954,
   "nextml/caption-contest-data contest 707.csv": 10658,
   "nextml/caption-contest-data contest 708.csv": 9122,
   "nextml/caption-contest-data contest 709.csv": 9603,
   "nextml/caption-contest-data contest 712.csv": 10641,
   "nextml/caption-contest-data contest 713.csv": 9401,
   "nextml/caption-contest-data contest 715.csv": 10095,
   "nextml/caption-contest-data contest 716.csv": 15228,
   "nextml/caption-contest-data contest 717.csv": 9530,
   "nextml/caption-contest-data contest 718.csv": 9073,
   "nextml/caption-contest-data contest 719.csv": 10025,
   "nextml/caption-contest-data contest 722.csv": 9792,
   "nextml/caption-contest-data contest 727.csv": 9652,
   "nextml/caption-contest-data contest 733.csv": 10112,
   "nextml/caption-contest-data contest 740.csv": 11050,
   "nextml/caption-contest-data contest 744.csv": 12164,
   "nextml/caption-contest-data contest 745.csv": 9603,
   "nextml/caption-contest-data contest 746.csv": 9438,
   "nextml/caption-contest-data contest 747.csv": 9687,
   "nextml/caption-contest-data contest 753.csv": 10914,
   "nextml/caption-contest-data contest 756.csv": 9273,
   "nextml/caption-contest-data contest 759.csv": 9313,
   "nextml/caption-contest-data contest 761.csv": 10633,
   "nextml/caption-contest-data contest 763.csv": 8962,
   "reddit:r/Jokes (bulk)": 98516,
   "taivop/joke-dataset (reddit r/jokes (taivop dump))": 185453,
   "taivop/joke-dataset (wocka.com)": 10006
  },
  "top_source": [
   "nextml/caption-contest-data (all contests)",
   2246476
  ],
  "top_source_share": 0.7099
 },
 "corpus_probe": {
  "n_captions": 2186939,
  "n_contests": 371,
  "vote_total_vs_votes_field_mismatch": 7061,
  "votes": {
   "min": 1.0,
   "median": 83.0,
   "mean": 126.3683189151595,
   "max": 25887.0,
   "share_ge_20": 0.9513882188757894,
   "share_ge_50": 0.8321050564281857,
   "share_ge_100": 0.36131414730817824
  },
  "recomputed_mean_max_abs_diff": 0.2168674698795181,
  "recomputed_mean_disagree_gt_1e6": 27829,
  "within_contest_dup_groups": 17,
  "within_contest_dup_groups_identical_counts": 0,
  "within_contest_dup_groups_distinct_counts": 17,
  "texts_in_multiple_contests": 2492,
  "max_contests_for_one_text": 4,
  "contests_with_multiple_sources": 0,
  "captions_per_contest": {
   "min": 342,
   "median": 5631,
   "max": 15228
  }
 },
 "model": {
  "receipt_type": "caption_model_vs_bounds",
  "receipt_version": 2,
  "ts": "2026-07-26T21:14:11",
  "question": "how much of the achievable caption signal do structural text features actually capture?",
  "protocol": {
   "target": "percentile standing within the caption's own contest, computed on the full contest before subsampling",
   "cv": "GroupKFold over contests, 5 folds — a held-out contest is an unseen drawing",
   "model": "HistGradientBoostingRegressor(max_iter=300, lr=0.06)",
   "features": [
    "caps_words",
    "digits",
    "echo_frac",
    "end_rhyme",
    "exclaims",
    "pair_alliteration",
    "pair_assonance",
    "punch_alliteration",
    "punch_assonance",
    "punch_chars",
    "punch_mean_wordlen",
    "punch_rarity_final",
    "punch_rarity_max",
    "punch_rarity_mean",
    "punch_syl_per_word",
    "punch_syllables",
    "punch_words",
    "questions",
    "quotes",
    "sentences",
    "setup_chars",
    "setup_mean_wordlen",
    "setup_rarity_final",
    "setup_rarity_max",
    "setup_rarity_mean",
    "setup_syllables",
    "setup_words",
    "syllable_ratio",
    "type_token_ratio",
    "word_ratio"
   ],
   "per_contest_sample": 600,
   "seed": 20260726
  },
  "n_rows": 215465,
  "n_contests": 360,
  "results": {
   "within_contest_median_spearman": 0.1555,
   "within_contest_iqr": [
    0.117325,
    0.18975
   ],
   "high_vote_subset_spearman": 0.10375,
   "pooled_spearman": 0.1538,
   "random_split_same_contests_spearman": 0.1541,
   "contests_above_chance": 358,
   "contests_scored": 360
  },
  "bounds": {
   "label_ceiling": 0.8262266476511767,
   "text_only_bound": 0.41097445176069036,
   "achieved_over_text_only_bound": 0.3783690186429091,
   "achieved_over_label_ceiling": 0.1882050166767924,
   "sources": [
    "jestry_out/caption_ceiling.json",
    "jestry_out/caption_portability.json"
   ]
  },
  "status": "complete",
  "core_runtime_s": 3880.9,
  "completed_ts": "2026-07-26T21:35:23.231229Z",
  "runtime_s": 5153.1,
  "runtime_note": "Core runtime was written by the process. Total runtime was reconstructed from its core timestamp and final receipt mtime because this run predates the atomic checkpoint patch.",
  "transfer": {
   "caption_to_reddit": 0.0959,
   "caption_to_humicroedit": 0.049,
   "reddit_to_caption_within": -0.00285,
   "humicroedit_to_caption_within": 0.0471
  },
  "transfer_note": "caption arms are evaluated WITHIN contest (median over contests); the reddit and humicroedit arms are pooled, since neither corpus has a controlled context to hold fixed"
 },
 "instrument": {
  "receipt_type": "instrument_rowslice_check",
  "receipt_version": 1,
  "ts": "2026-07-26T17:18:41",
  "question": "does widening one score row at a time instead of the whole buffer change any measured NLL?",
  "gguf": "gemma-2-2b-it-Q4_K_M.gguf",
  "n_ctx": 2048,
  "cases": [
   {
    "context": "I told my wife she should embrace her mistakes.",
    "continuation": " She gave me a hug.",
    "identical": true,
    "n_tokens": 6,
    "mean_nll_old": 2.7849,
    "mean_nll_new": 2.7849,
    "max_abs_diff": 0.0
   },
   {
    "context": "Why did the scarecrow win an award?",
    "continuation": " He was outstanding in his field.",
    "identical": true,
    "n_tokens": 7,
    "mean_nll_old": 1.3587,
    "mean_nll_new": 1.3587,
    "max_abs_diff": 0.0
   },
   {
    "context": "They put speed bumps outside the school.",
    "continuation": " I've hit six kids already.",
    "identical": true,
    "n_tokens": 8,
    "mean_nll_old": 3.8616,
    "mean_nll_new": 3.8616,
    "max_abs_diff": 0.0
   },
   {
    "context": "A horse walks into a bar.",
    "continuation": " The bartender says, why the long face?",
    "identical": true,
    "n_tokens": 9,
    "mean_nll_old": 1.642,
    "mean_nll_new": 1.642,
    "max_abs_diff": 0.0
   },
   {
    "context": "The sky is blue today.",
    "continuation": " The sky is blue today.",
    "identical": true,
    "n_tokens": 6,
    "mean_nll_old": 2.0618,
    "mean_nll_new": 2.0618,
    "max_abs_diff": 0.0
   }
  ],
  "all_identical": true,
  "seconds_old_path": 238.14,
  "seconds_new_path": 208.68,
  "speedup": 1.14,
  "note": "timings are from a machine under heavy concurrent load (load avg ~90 on 16 cores), so the ratio is more meaningful than either absolute"
 },
 "_provenance": {
  "built_utc": "2026-07-26T21:36:16Z",
  "receipt_files": {
   "caption_ceiling.json": {
    "mtime_utc": "2026-07-26T16:41:16Z",
    "sha256_12": "0d4bcdfe6355",
    "bytes": 140228
   },
   "caption_portability.json": {
    "mtime_utc": "2026-07-26T16:43:32Z",
    "sha256_12": "f9c32f3248a0",
    "bytes": 4505
   },
   "form_signal_receipts.jsonl": {
    "mtime_utc": "2026-07-26T19:12:35Z",
    "sha256_12": "2cdd3f8a46c7",
    "bytes": 1349
   },
   "corpus_census.json": {
    "mtime_utc": "2026-07-26T19:47:21Z",
    "sha256_12": "e4ad8f1c3e70",
    "bytes": 5106
   },
   "caption_corpus_probe.json": {
    "mtime_utc": "2026-07-26T16:36:11Z",
    "sha256_12": "370189de0a05",
    "bytes": 749
   },
   "caption_model.json": {
    "mtime_utc": "2026-07-26T21:36:16Z",
    "sha256_12": "284ba65972c8",
    "bytes": 2658
   },
   "instrument_rowslice_check.json": {
    "mtime_utc": "2026-07-26T17:18:41Z",
    "sha256_12": "f26c05f1cbf2",
    "bytes": 1806
   }
  },
  "missing": [],
  "note": "receipts embedded at build time; this notebook is a snapshot, not a re-run; static edition — snapshot time is the newest receipt mtime",
  "nonce": "49f7bc7743d0"
 }
}''')
prov = RECEIPTS['_provenance']
NONCE = prov['nonce']
print('built', prov['built_utc'], '| nonce', NONCE)
for fname, s in prov['receipt_files'].items():
    print(f"  {fname:<34} {s['bytes']:>8} B  sha256:{s['sha256_12']}  {s['mtime_utc']}")
if prov['missing']:
    print('MISSING (panels for these are skipped, not faked):', prov['missing'])

# %%
# ---- the three headline numbers ----
ceil = RECEIPTS['ceiling']['headline']
port = RECEIPTS['portability']['results']
LABEL_CEILING = ceil['median_ceiling']
TEXT_BOUND    = port['text_only_predictor_bound']
PORTABLE      = port['portable_share']
model = RECEIPTS.get('model')
ACHIEVED = model['results']['within_contest_median_spearman'] if model else None

print(f'label ceiling (vote noise)        rho <= {LABEL_CEILING:.3f}')
print(f'text-only bound (context)         rho <= {TEXT_BOUND:.3f}')
print(f'share of standing carried by words  {PORTABLE:.1%}')
print('achieved by structural features    '
      + (f'rho = {ACHIEVED:.3f}' if ACHIEVED is not None
         else 'not embedded in this build (model receipt absent)'))

# %%
# ---- chart setup: dark surface, validated categorical slots ----
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from matplotlib import rcParams
SERIES = ['#3987e5', '#d95926', '#199e70']
SURFACE, INK, INK2, GRID = '#1a1a19', '#ffffff', '#c3c2b7', '#3a3a37'
rcParams.update({
    'figure.facecolor': SURFACE, 'axes.facecolor': SURFACE,
    'savefig.facecolor': SURFACE,
    'text.color': INK, 'axes.labelcolor': INK2, 'axes.edgecolor': GRID,
    'xtick.color': INK2, 'ytick.color': INK2,
    'axes.spines.top': False, 'axes.spines.right': False,
    'font.size': 11, 'figure.dpi': 120,
})
def bare(ax):
    ax.grid(axis='x', color=GRID, linewidth=0.6, alpha=0.7)
    ax.set_axisbelow(True)
print('charts configured')

# %% [markdown]
# ## 1. The ceiling, and what a model actually reaches
#
# Two estimators of the label's reliability, on unrelated assumptions: split-half resampling of each caption's own votes, and the multinomial sampling variance of its mean. Compared like-for-like they agree to **0.003** — that agreement is the receipt; the ceiling is what it implies.

# %%
fig, ax = plt.subplots(figsize=(8, 2.9))
rows = [('label ceiling\n(vote noise)', LABEL_CEILING, SERIES[0]),
        ('text-only bound\n(context dependence)', TEXT_BOUND, SERIES[1])]
if ACHIEVED is not None:
    rows.append(('achieved\n(structural features)', ACHIEVED, SERIES[2]))
ys = range(len(rows))
ax.barh(list(ys), [r[1] for r in rows], color=[r[2] for r in rows],
        height=0.52, zorder=3)
for y, (lab, v, c) in zip(ys, rows):
    ax.text(v + 0.012, y, f'{v:.3f}', va='center', color=INK, fontweight='bold')
ax.set_yticks(list(ys)); ax.set_yticklabels([r[0] for r in rows], color=INK2)
ax.invert_yaxis(); ax.set_xlim(0, 1.0)
ax.set_xlabel('Spearman against the published crowd mean, within contest')
ax.set_title('A score is only readable against what is achievable', color=INK,
             loc='left', fontweight='bold')
bare(ax); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 2. Reliability rises with votes, exactly as sampling error must
#
# The third check that the estimator measures what it claims. It also prices future data collection: a rated corpus with 30 votes per item cannot support a model comparison finer than its own ceiling.

# %%
bv = RECEIPTS['ceiling']['by_vote_count']
labs = [f"{b['median_votes_lo']}–{b['median_votes_hi'] if b['median_votes_hi'] < 10**9 else '+'}"
        for b in bv]
fig, ax = plt.subplots(figsize=(8, 3.2))
xs = range(len(bv))
ax.plot(list(xs), [b['ceiling'] for b in bv], color=SERIES[0], linewidth=2,
        marker='o', markersize=9, label='ceiling on Spearman', zorder=3)
ax.plot(list(xs), [b['reliability'] for b in bv], color=SERIES[2], linewidth=2,
        marker='o', markersize=9, label='label reliability', zorder=3)
for x, b in zip(xs, bv):
    ax.annotate(f"{b['ceiling']:.2f}", (x, b['ceiling']), textcoords='offset points',
                xytext=(0, 9), ha='center', color=INK, fontsize=10)
ax.set_xticks(list(xs)); ax.set_xticklabels(labs)
ax.set_xlabel('votes per caption'); ax.set_ylim(0.5, 1.0)
ax.set_title('More votes, less label noise, higher achievable score', color=INK,
             loc='left', fontweight='bold')
ax.legend(frameon=False, labelcolor=INK2, loc='lower right')
ax.grid(axis='y', color=GRID, linewidth=0.6, alpha=0.7); ax.set_axisbelow(True)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3. The same words, a different drawing
#
# 2,173 caption texts were submitted to more than one contest. Arm 2 is what arm 1 would read if context were irrelevant, computed on the same items. Arm 3 shuffles the partner and must read zero — it is what makes the ratio a measurement rather than an artifact.

# %%
arms = [('cross-context\nsame words, new drawing', port['cross_context_spearman'], SERIES[1]),
        ('same-context ceiling\nsplit-half of own votes', port['same_context_ceiling_spearman'], SERIES[0]),
        ('placebo\nshuffled partner', port['placebo_spearman'], SERIES[2])]
fig, ax = plt.subplots(figsize=(8, 2.9))
ys = range(len(arms))
ax.barh(list(ys), [a[1] for a in arms], color=[a[2] for a in arms], height=0.52, zorder=3)
for y, (lab, v, c) in zip(ys, arms):
    ax.text(v + 0.012, y, f'{v:+.3f}', va='center', color=INK, fontweight='bold')
ax.set_yticks(list(ys)); ax.set_yticklabels([a[0] for a in arms], color=INK2, fontsize=10)
ax.invert_yaxis(); ax.set_xlim(0, 0.8)
ax.set_xlabel('Spearman')
ax.set_title(f'Only {PORTABLE:.0%} of a caption\u2019s standing travels with its words',
             color=INK, loc='left', fontweight='bold')
bare(ax); plt.tight_layout(); plt.show()

print('most context-dependent captions in the corpus:')
for ex in RECEIPTS['portability']['examples_most_context_dependent'][:4]:
    print(f"  {ex['standing_a']:.2f} -> {ex['standing_b']:.2f}   {ex['text'][:78]!r}")

# %% [markdown]
# ## 4. A null worth keeping
#
# Does joke FORM change what the certified instrument (gemma-2-2b-it Q4_K_M through llama.cpp) finds surprising? Deterministic sample, S only, a proverb control arm. **No form's interval clears the control.** The form labels themselves were repaired first: `limerick` had been matching any sentence opening "There was a…" (652 hits, now 8 rhyme-verified) and `yo_mama` any mention of a mother (7,177 hits, of which 5,773 were Chuck Norris facts).

# %%
fs = RECEIPTS.get('form_signal')
if not fs:
    print('form-signal receipt not embedded in this build')
else:
    pf = fs['per_form']
    ctrl = pf.get('control_proverb')
    forms = [(k, v) for k, v in pf.items() if k != 'control_proverb']
    forms.sort(key=lambda kv: -kv[1]['mean_S'])
    order = forms + ([('control_proverb', ctrl)] if ctrl else [])
    fig, ax = plt.subplots(figsize=(8, 4.6))
    for i, (name, d) in enumerate(order):
        is_ctrl = name == 'control_proverb'
        c = SERIES[1] if is_ctrl else SERIES[0]
        lo, hi = d['ci95']
        ax.plot([lo, hi], [i, i], color=c, linewidth=2, solid_capstyle='round', zorder=3)
        ax.plot([d['mean_S']], [i], marker='o', markersize=9, color=c, zorder=4)
    if ctrl:
        ax.axvline(ctrl['ci95'][1], color=SERIES[1], linestyle='--', linewidth=1.2,
                   alpha=0.8, zorder=2)
    ax.set_yticks(range(len(order)))
    ax.set_yticklabels([n.replace('_', ' ') for n, _ in order], color=INK2)
    ax.invert_yaxis()
    ax.set_xlabel('mean S (punchline surprisal), 95% bootstrap CI')
    ax.set_title(fs['verdict'][:78], color=INK, loc='left', fontweight='bold')
    bare(ax); plt.tight_layout(); plt.show()
    print(fs['verdict'])
    print('caveat:', fs['caveat'])

# %% [markdown]
# ## Where this sits
#
# - Canonical executable study (corpus, taxonomy, Gemma measurement, the 0/10 form null in full): [Humor Genome Wave 2](https://www.kaggle.com/code/taylorsamarel/humor-genome-wave-2-reproducible-gemma-study)
# - Deterministic causal controls (four arms from one premise, CC0): [Open Controls Causal Design Lab](https://www.kaggle.com/code/taylorsamarel/humor-genome-open-controls-causal-design-lab)
# - Source, receipts, and the evidence scoreboard: [aidonerightcorp/humorvibes-jestry](https://github.com/aidonerightcorp/humorvibes-jestry)
#
# Every number above is a stored receipt, displayed — not a claim that any model understands humor, and not human evidence.
